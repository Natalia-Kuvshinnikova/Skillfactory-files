# %%
import pandas as pd
df_train = pd.read_csv('data/hotels_train.csv') # датасет для обучения
df_test = pd.read_csv('data/hotels_test.csv') # датасет для предсказания
sample_submission = pd.read_csv('data/submission.csv') # самбмишн
df_train['sample'] = 1 # помечаем где у нас трейн
df_test['sample'] = 0 # помечаем где у нас тест
df_test['reviewer_score'] = 0 # в тесте у нас нет значения reviewer_score, мы его должны предсказать, по этому пока просто заполняем нулями

hotels = pd.concat([df_test, df_train], ignore_index=True, sort=False)
hotels.head()
# Out:
#                                        hotel_address  \
# 0                 Via Senigallia 6 20161 Milan Italy
# 1  Arlandaweg 10 Westpoort 1043 EW Amsterdam Neth...
# 2        Mallorca 251 Eixample 08008 Barcelona Spain
# 3  Piazza Della Repubblica 17 Central Station 201...
# 4  Singel 303 309 Amsterdam City Center 1012 WJ A...
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           904   7/21/2017            8.1
# 1                           612  12/12/2016            8.6
# 2                            46  11/26/2015            8.3
# 3                           241  10/17/2015            9.1
# 4                           834   5/16/2016            9.1
#
#                                    hotel_name        reviewer_nationality  \
# 0                              Hotel Da Vinci             United Kingdom
# 1                           Urban Lodge Hotel                    Belgium
# 2  Alexandra Barcelona A DoubleTree by Hilton                     Sweden
# 3                    Hotel Principe Di Savoia   United States of America
# 4                              Hotel Esther a             United Kingdom
#
#                                      negative_review  \
# 0   Would have appreciated a shop in the hotel th...
# 1        No tissue paper box was present at the room
# 2                                           Pillows
# 3                                        No Negative
# 4                                        No Negative
#
#    review_total_negative_word_counts  total_number_of_reviews  \
# 0                                 52                    16670
# 1                                 10                     5018
# 2                                  3                      351
# 3                                  0                     1543
# 4                                  0                     4687
#
#                                      positive_review  \
# 0   Hotel was great clean friendly staff free bre...
# 1                                        No Positive
# 2                         Nice welcoming and service
# 3   Everything including the nice upgrade The Hot...
# 4                    Lovely hotel v welcoming staff
#
#    review_total_positive_word_counts  \
# 0                                 62
# 1                                  0
# 2                                  5
# 3                                 27
# 4                                  7
#
#    total_number_of_reviews_reviewer_has_given  \
# 0                                           1
# 1                                           7
# 2                                          15
# 3                                           9
# 4                                           2
#
#                                                 tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Double Room '...           13 days
# 1  [' Leisure trip ', ' Group ', ' Triple Room ',...           234 day
# 2  [' Business trip ', ' Solo traveler ', ' Twin ...           616 day
# 3  [' Leisure trip ', ' Couple ', ' Ambassador Ju...           656 day
# 4  [' Business trip ', ' Solo traveler ', ' Class...           444 day
#
#          lat       lng  sample  reviewer_score
# 0  45.533137  9.171102       0             0.0
# 1  52.385649  4.834443       0             0.0
# 2  41.393192  2.161520       0             0.0
# 3  45.479888  9.196298       0             0.0
# 4  52.370545  4.888644       0             0.0

# %% [markdown]
# # Исследование данных

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 18 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               515738 non-null  object
#  1   additional_number_of_scoring                515738 non-null  int64
#  2   review_date                                 515738 non-null  object
#  3   average_score                               515738 non-null  float64
#  4   hotel_name                                  515738 non-null  object
#  5   reviewer_nationality                        515738 non-null  object
#  6   negative_review                             515738 non-null  object
#  7   review_total_negative_word_counts           515738 non-null  int64
#  8   total_number_of_reviews                     515738 non-null  int64
#  9   positive_review                             515738 non-null  object
#  10  review_total_positive_word_counts           515738 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  515738 non-null  int64
#  12  tags                                        515738 non-null  object
#  13  days_since_review                           515738 non-null  object
#  14  lat                                         512470 non-null  float64
#  15  lng                                         512470 non-null  float64
#  16  sample                                      515738 non-null  int64
#  17  reviewer_score                              515738 non-null  float64
# dtypes: float64(4), int64(6), object(8)
# memory usage: 70.8+ MB

# %% [markdown]
# Основная статистическая информация

# %%
hotels.describe()
# Out:
#        additional_number_of_scoring  average_score  \
# count                 515738.000000  515738.000000
# mean                     498.081836       8.397487
# std                      500.538467       0.548048
# min                        1.000000       5.200000
# 25%                      169.000000       8.100000
# 50%                      341.000000       8.400000
# 75%                      660.000000       8.800000
# max                     2682.000000       9.800000
#
#        review_total_negative_word_counts  total_number_of_reviews  \
# count                      515738.000000            515738.000000
# mean                           18.539450              2743.743944
# std                            29.690831              2317.464868
# min                             0.000000                43.000000
# 25%                             2.000000              1161.000000
# 50%                             9.000000              2134.000000
# 75%                            23.000000              3613.000000
# max                           408.000000             16670.000000
#
#        review_total_positive_word_counts  \
# count                      515738.000000
# mean                           17.776458
# std                            21.804185
# min                             0.000000
# 25%                             5.000000
# 50%                            11.000000
# 75%                            22.000000
# max                           395.000000
#
#        total_number_of_reviews_reviewer_has_given            lat  \
# count                               515738.000000  512470.000000
# mean                                     7.166001      49.442439
# std                                     11.040228       3.466325
# min                                      1.000000      41.328376
# 25%                                      1.000000      48.214662
# 50%                                      3.000000      51.499981
# 75%                                      8.000000      51.516288
# max                                    355.000000      52.400181
#
#                  lng         sample  reviewer_score
# count  512470.000000  515738.000000   515738.000000
# mean        2.823803       0.749999        6.297672
# std         4.579425       0.433014        3.902295
# min        -0.369758       0.000000        0.000000
# 25%        -0.143372       0.250000        0.625000
# 50%         0.010607       1.000000        7.900000
# 75%         4.834443       1.000000        9.600000
# max        16.429233       1.000000       10.000000

# %%
#выводим имена столбцов

hotels.columns
# Out:
# Index(['hotel_address', 'additional_number_of_scoring', 'review_date',
#        'average_score', 'hotel_name', 'reviewer_nationality',
#        'negative_review', 'review_total_negative_word_counts',
#        'total_number_of_reviews', 'positive_review',
#        'review_total_positive_word_counts',
#        'total_number_of_reviews_reviewer_has_given', 'tags',
#        'days_since_review', 'lat', 'lng', 'sample', 'reviewer_score'],
#       dtype='object')

# %%
# непрерывные признаки
num_cols = ['additional_number_of_scoring','average_score', 'total_number_of_reviews', 
            'review_total_negative_word_counts', 'review_total_positive_word_counts', 
            'total_number_of_reviews_reviewer_has_given',  'lat', 'lng']

# категориальные признаки
cat_cols = ['hotel_address', 'review_date','hotel_name', 
             'reviewer_nationality', 'negative_review', 'positive_review', 
             'tags', 'days_since_review' ]

# %% [markdown]
# ## Преобразование данных и добавление новых признаков

# %%
# признак уникальных названий отелей

hotels['unique_names'] = hotels['hotel_name'].unique().shape[0]
hotels['unique_names']
# Out:
# 0         1492
# 1         1492
# 2         1492
# 3         1492
# 4         1492
#           ...
# 515733    1492
# 515734    1492
# 515735    1492
# 515736    1492
# 515737    1492
# Name: unique_names, Length: 515738, dtype: int64

# %% [markdown]
# ### Расстояние от каждого отеля до центра

# %%
# выделяем город и страну 
hotels['country'] = hotels['hotel_address'].apply(
    lambda x: x.split()[-1] 
        if x.split()[-1] != 'Kingdom'
        else ' '.join(x.split()[-2:])
)
    
hotels['city'] = hotels.apply(
    lambda x: x['hotel_address'].split()[-5] 
        if x['country'] == 'United Kingdom'
        else x['hotel_address'].split()[-2], axis=1
)
display(hotels[['country', 'city']].value_counts())
# Out:
# country         city
# United Kingdom  London       262301
# Spain           Barcelona     60149
# France          Paris         59928
# Netherlands     Amsterdam     57214
# Austria         Vienna        38939
# Italy           Milan         37207
# Name: count, dtype: int64

# %%
# создаем датафрейм, содержащий численность населения и координаты городов
population_df = pd.DataFrame(
    [
        ['London', 8.982, 51.50735, -0.12776], 
        ['Barcelona', 1.62, 41.3888, 2.15899], 
        ['Paris', 2.161, 48.85661, 2.35222], 
        ['Amsterdam', 0.822, 52.37022, 4.89517], 
        ['Vienna', 1.897, 48.20817, 16.37382], 
        ['Milan', 1.352, 45.45863, 9.18187]
    ], 
    columns=['city', 'city_population', 'center_lat', 'center_lng']
)
hotels = hotels.merge(population_df, how='left', on='city')

# %%
# кодировка названи городов
import category_encoders as ce

encoder = ce.OneHotEncoder(cols=['city']) # указываем столбец для кодирования
type_bin = encoder.fit_transform(hotels['city'])
type_bin = type_bin.rename(columns={'city_1':'London','city_2':'Paris','city_3':'Amsterdam','city_4':'Milan','city_5':'Vienna','city_6':'Barcelona'})
hotels = pd.concat([hotels, type_bin], axis=1)

# %%
# соединяем название города и название отеля (когда сеть отелей представлена в разных городах)
hotels['hotel_name'] = hotels.apply(lambda i: ' '.join([i.hotel_name, i.city]), axis=1)

# %%
hotels.groupby(['hotel_name', 'hotel_address'], as_index=False).count().hotel_name.value_counts()[:15]
# Out:
# hotel_name
# 11 Cadogan Gardens London                                1
# Mercure Paris Gare De Lyon TGV Paris                     1
# Mercure Paris Opera Louvre Paris                         1
# Mercure Paris Opera Grands Boulevards Paris              1
# Mercure Paris Opera Garnier Paris                        1
# Mercure Paris Op ra Faubourg Montmartre Paris            1
# Mercure Paris Notre Dame Saint Germain des Pr s Paris    1
# Mercure Paris Montparnasse Raspail Paris                 1
# Mercure Paris Montmartre Sacr Coeur Paris                1
# Mercure Paris Gobelins Place d Italie Paris              1
# Mercure Paris Gare Montparnasse Paris                    1
# Mercure Paris Champs Elys es Paris                       1
# Mercure London Paddington Hotel London                   1
# Mercure Paris Centre Tour Eiffel Paris                   1
# Mercure Paris Bercy Biblioth que Paris                   1
# Name: count, dtype: int64

# %%
# определим координаты по адресу там, где они пропущены
from geopy.distance import geodesic
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="openstreetmap.org")
df_empty_lat = hotels[pd.isna(hotels['lat'])].groupby(
    ['hotel_name', 'hotel_address'],
    as_index=False
)[['lat', 'lng']].sum()
for ind, row in df_empty_lat.iterrows():
    address = row['hotel_address']
    location = geolocator.geocode(address, timeout=None)
    if not location:
        address_index = ' '.join(address.split()[-3:])
        location = geolocator.geocode(address_index, timeout=None)
    if location:
        df_empty_lat.loc[ind, 'lat'] = location.latitude
        df_empty_lat.loc[ind, 'lng'] = location.longitude

df_empty_lat.drop(['hotel_address'], axis=1, inplace=True)   
hotels = hotels.merge(df_empty_lat, how='left', on='hotel_name', suffixes=('', '_geo'))
hotels.loc[pd.isna(hotels['lat']), 'lat'] = hotels['lat_geo']
hotels.loc[pd.isna(hotels['lng']), 'lng'] = hotels['lng_geo']
hotels.drop(['lat_geo', 'lng_geo'], axis=1, inplace=True)

# %%
hotels.info()
# больше нет пропусков в lat и lng
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 30 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               515738 non-null  object
#  1   additional_number_of_scoring                515738 non-null  int64
#  2   review_date                                 515738 non-null  object
#  3   average_score                               515738 non-null  float64
#  4   hotel_name                                  515738 non-null  object
#  5   reviewer_nationality                        515738 non-null  object
#  6   negative_review                             515738 non-null  object
#  7   review_total_negative_word_counts           515738 non-null  int64
#  8   total_number_of_reviews                     515738 non-null  int64
#  9   positive_review                             515738 non-null  object
#  10  review_total_positive_word_counts           515738 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  515738 non-null  int64
#  12  tags                                        515738 non-null  object
#  13  days_since_review                           515738 non-null  object
#  14  lat                                         515738 non-null  float64
#  15  lng                                         515738 non-null  float64
#  16  sample                                      515738 non-null  int64
#  17  reviewer_score                              515738 non-null  float64
#  18  unique_names                                515738 non-null  int64
#  19  country                                     515738 non-null  object
#  20  city                                        515738 non-null  object
#  21  city_population                             515738 non-null  float64
#  22  center_lat                                  515738 non-null  float64
#  23  center_lng                                  515738 non-null  float64
#  24  London                                      515738 non-null  int64
#  25  Paris                                       515738 non-null  int64
#  26  Amsterdam                                   515738 non-null  int64
#  27  Milan                                       515738 non-null  int64
#  28  Vienna                                      515738 non-null  int64
#  29  Barcelona                                   515738 non-null  int64
# dtypes: float64(7), int64(13), object(10)
# memory usage: 118.0+ MB

# %%
# вычисляем расстояние до центра города
df_hotels_grouped = hotels.groupby(['hotel_name'], as_index=False)[['lat', 'lng', 'center_lat', 'center_lng']].max()
df_hotels_grouped['center_distance'] = df_hotels_grouped.apply(lambda x: geodesic((x.lat, x.lng), (x.center_lat, x.center_lng), ellipsoid='WGS-84').km, axis=1)
df_hotels_grouped.drop(['lat', 'lng', 'center_lat', 'center_lng'], axis=1, inplace=True)
hotels = hotels.merge(df_hotels_grouped, how='left', on='hotel_name')
hotels.drop(['center_lat', 'center_lng', 'lat', 'lng'], axis=1, inplace=True)

# %%
hotels['center_distance']
# Out:
# 0         8.323504
# 1         4.477639
# 2         0.531680
# 3         2.618222
# 4         0.445957
#             ...
# 515733    4.637993
# 515734    2.591001
# 515735    1.513508
# 515736    2.403793
# 515737    4.616806
# Name: center_distance, Length: 515738, dtype: float64

# %%
# построим гистограмму распределения расстояния до центра города
import plotly.express as px
fig = px.histogram(
    data_frame=hotels.groupby('hotel_name', as_index=False).center_distance.min(),
    x='center_distance',
    title='Распределение расстояния отеля до центра',
    nbins=90,
    marginal='box',
    width=1000,
)
fig.show()

# %% [markdown]
# ### Обработка признака имени отеля

# %%
bin_encoder = ce.BinaryEncoder(cols=['hotel_name']) # указываем столбец для кодирования 
type_bin = bin_encoder.fit_transform(hotels['hotel_name']) 
hotels = pd.concat([hotels, type_bin], axis=1)

# %% [markdown]
# ### Обработка признака 'country'

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
hotels['country_encoded'] = label_encoder.fit_transform(hotels['country'])

# One-Hot Encoding
hotels_encoded = pd.get_dummies(hotels, columns=['country'], prefix='country')

# %% [markdown]
# ### Признак категории отеля

# %%
category_mapping = {'Бизнес': 1, 'Развлечения': 2, 'Общий': 3}

# Создание функции для определения категории отеля
def get_hotel_category(tags):
    if 'Business' in tags:
        return 'Бизнес'
    elif 'Leisure' in tags:
        return 'Развлечения'
    else:
        return 'Общий'

# Применение функции к столбцу 'tags' и создание нового столбца 'hotel_category'
hotels['hotel_category'] = hotels['tags'].apply(get_hotel_category).map(category_mapping)
hotels['hotel_category'].tail()
# Out:
# 515733    2
# 515734    2
# 515735    1
# 515736    2
# 515737    2
# Name: hotel_category, dtype: int64

# %% [markdown]
# ### Обработка признака 'reviewer_nationality'

# %%
# признак страны для отелей
hotels['country'] = hotels['hotel_address'].apply(lambda x: x.split()[-1] if x.split()[-1] != 'Kingdom' \
                                                                      else ' '.join(x.split()[-2:]))

# убераем пробелы в названии места жительства резидента
hotels['reviewer_nationality'] = hotels['reviewer_nationality'].apply(lambda x: x[1:-1])

# создадаём признак,определяющий иностранец или местный житель  писал отзыв
hotels['local_reviewer'] = hotels.apply(lambda x: 1 if x['reviewer_nationality'] == x['country'] 
                                                else 0, axis=1)

hotels['local_reviewer'].value_counts(normalize=True)
# Out:
# local_reviewer
# 0    0.654082
# 1    0.345918
# Name: proportion, dtype: float64

# %%
hotels['reviewer_nationality'].nunique(dropna=False)
# Out:
# 227

# %%
# применяем бинарное колдирование к признаку 'reviewer_nationality'
bin_encoder = ce.BinaryEncoder(cols=['reviewer_nationality'])
type_bin = bin_encoder.fit_transform(hotels['reviewer_nationality'])

hotels = pd.concat([hotels, type_bin], axis=1)

# %%
# составим круговую диаграмму 10 стран, резиденты которых чащевсего оставляли отзывы
import matplotlib.pyplot as plt
reviewer_data = hotels['reviewer_nationality'].value_counts().nlargest(10)
fig = plt.figure(figsize=(5, 5))
axes = fig.add_axes([0, 0, 1, 1])
axes.pie(
    reviewer_data,
    labels = reviewer_data.index,
    autopct = '%.1f%%'
);

# %% [markdown]
# ### Отношение негативных и позитивных слов к общему количеству слов в отзыве.

# %%
# Вычисление отношения негативных и позитивных слов к общему количеству слов в отзыве
total_word_counts = hotels['review_total_negative_word_counts'] + hotels['review_total_positive_word_counts']
hotels['Negative_Word_Ratio'] = hotels['review_total_negative_word_counts'] / total_word_counts
hotels['Positive_Word_Ratio'] = hotels['review_total_positive_word_counts'] / total_word_counts

hotels.head()
# Out:
#                                        hotel_address  \
# 0                 Via Senigallia 6 20161 Milan Italy
# 1  Arlandaweg 10 Westpoort 1043 EW Amsterdam Neth...
# 2        Mallorca 251 Eixample 08008 Barcelona Spain
# 3  Piazza Della Repubblica 17 Central Station 201...
# 4  Singel 303 309 Amsterdam City Center 1012 WJ A...
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           904   7/21/2017            8.1
# 1                           612  12/12/2016            8.6
# 2                            46  11/26/2015            8.3
# 3                           241  10/17/2015            9.1
# 4                           834   5/16/2016            9.1
#
#                                           hotel_name  \
# 0                               Hotel Da Vinci Milan
# 1                        Urban Lodge Hotel Amsterdam
# 2  Alexandra Barcelona A DoubleTree by Hilton Bar...
# 3                     Hotel Principe Di Savoia Milan
# 4                           Hotel Esther a Amsterdam
#
#        reviewer_nationality  \
# 0            United Kingdom
# 1                   Belgium
# 2                    Sweden
# 3  United States of America
# 4            United Kingdom
#
#                                      negative_review  \
# 0   Would have appreciated a shop in the hotel th...
# 1        No tissue paper box was present at the room
# 2                                           Pillows
# 3                                        No Negative
# 4                                        No Negative
#
#    review_total_negative_word_counts  total_number_of_reviews  \
# 0                                 52                    16670
# 1                                 10                     5018
# 2                                  3                      351
# 3                                  0                     1543
# 4                                  0                     4687
#
#                                      positive_review  ...  \
# 0   Hotel was great clean friendly staff free bre...  ...
# 1                                        No Positive  ...
# 2                         Nice welcoming and service  ...
# 3   Everything including the nice upgrade The Hot...  ...
# 4                    Lovely hotel v welcoming staff   ...
#
#    reviewer_nationality_0  reviewer_nationality_1 reviewer_nationality_2  \
# 0                       0                       0                      0
# 1                       0                       0                      0
# 2                       0                       0                      0
# 3                       0                       0                      0
# 4                       0                       0                      0
#
#   reviewer_nationality_3  reviewer_nationality_4  reviewer_nationality_5  \
# 0                      0                       0                       0
# 1                      0                       0                       0
# 2                      0                       0                       0
# 3                      0                       0                       1
# 4                      0                       0                       0
#
#    reviewer_nationality_6 reviewer_nationality_7 Negative_Word_Ratio  \
# 0                       0                      1             0.45614
# 1                       1                      0             1.00000
# 2                       1                      1             0.37500
# 3                       0                      0             0.00000
# 4                       0                      1             0.00000
#
#    Positive_Word_Ratio
# 0              0.54386
# 1              0.00000
# 2              0.62500
# 3              1.00000
# 4              1.00000
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Соотношение положительных и отрицательных отзывов

# %%
import numpy as np
# Расчет соотношения положительных и отрицательных отзывов
hotels['review_sentiment_ratio'] = hotels['review_total_positive_word_counts'] / hotels['review_total_negative_word_counts']
hotels['review_sentiment_ratio'].replace(np.inf, np.nan, inplace=True)
# Вывод результатов
display(hotels[['review_total_positive_word_counts', 'review_total_negative_word_counts', 'review_sentiment_ratio']])
# Out:
#         review_total_positive_word_counts  review_total_negative_word_counts  \
# 0                                      62                                 52
# 1                                       0                                 10
# 2                                       5                                  3
# 3                                      27                                  0
# 4                                       7                                  0
# ...                                   ...                                ...
# 515733                                 10                                  0
# 515734                                 93                                  0
# 515735                                  9                                 12
# 515736                                  6                                  0
# 515737                                 20                                 20
#
#         review_sentiment_ratio
# 0                     1.192308
# 1                     0.000000
# 2                     1.666667
# 3                          NaN
# 4                          NaN
# ...                        ...
# 515733                     NaN
# 515734                     NaN
# 515735                0.750000
# 515736                     NaN
# 515737                1.000000
#
# [515738 rows x 3 columns]

# %% [markdown]
# ### Анализ наличия определенных ключевых слов

# %%
# Задаем список ключевых слов или фраз для анализа
keywords = ['good', 'bad', 'excellent', 'poor', 'recommend']

# Создаем новые бинарные признаки для каждого ключевого слова или фразы
for keyword in keywords:
    hotels[keyword + '_present'] = hotels['positive_review'].str.contains(keyword, case=False) | hotels['negative_review'].str.contains(keyword, case=False)

# Выводим статистику по наличию ключевых слов или фраз
for keyword in keywords:
    keyword_present_count = hotels[keyword + '_present'].sum()
    print(f"Количество отзывов с упоминанием '{keyword}': {keyword_present_count}")
# Out:
# Количество отзывов с упоминанием 'good': 110093
# Количество отзывов с упоминанием 'bad': 12146
# Количество отзывов с упоминанием 'excellent': 59965
# Количество отзывов с упоминанием 'poor': 16600
# Количество отзывов с упоминанием 'recommend': 14433

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 57 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               515738 non-null  object
#  1   additional_number_of_scoring                515738 non-null  int64
#  2   review_date                                 515738 non-null  object
#  3   average_score                               515738 non-null  float64
#  4   hotel_name                                  515738 non-null  object
#  5   reviewer_nationality                        515738 non-null  object
#  6   negative_review                             515738 non-null  object
#  7   review_total_negative_word_counts           515738 non-null  int64
#  8   total_number_of_reviews                     515738 non-null  int64
#  9   positive_review                             515738 non-null  object
#  10  review_total_positive_word_counts           515738 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  515738 non-null  int64
#  12  tags                                        515738 non-null  object
#  13  days_since_review                           515738 non-null  object
#  14  sample                                      515738 non-null  int64
#  15  reviewer_score                              515738 non-null  float64
#  16  unique_names                                515738 non-null  int64
#  17  country                                     515738 non-null  object
#  18  city                                        515738 non-null  object
#  19  city_population                             515738 non-null  float64
#  20  London                                      515738 non-null  int64
#  21  Paris                                       515738 non-null  int64
#  22  Amsterdam                                   515738 non-null  int64
#  23  Milan                                       515738 non-null  int64
#  24  Vienna                                      515738 non-null  int64
#  25  Barcelona                                   515738 non-null  int64
#  26  center_distance                             515738 non-null  float64
#  27  hotel_name_0                                515738 non-null  int64
#  28  hotel_name_1                                515738 non-null  int64
#  29  hotel_name_2                                515738 non-null  int64
#  30  hotel_name_3                                515738 non-null  int64
#  31  hotel_name_4                                515738 non-null  int64
#  32  hotel_name_5                                515738 non-null  int64
#  33  hotel_name_6                                515738 non-null  int64
#  34  hotel_name_7                                515738 non-null  int64
#  35  hotel_name_8                                515738 non-null  int64
#  36  hotel_name_9                                515738 non-null  int64
#  37  hotel_name_10                               515738 non-null  int64
#  38  country_encoded                             515738 non-null  int32
#  39  hotel_category                              515738 non-null  int64
#  40  local_reviewer                              515738 non-null  int64
#  41  reviewer_nationality_0                      515738 non-null  int64
#  42  reviewer_nationality_1                      515738 non-null  int64
#  43  reviewer_nationality_2                      515738 non-null  int64
#  44  reviewer_nationality_3                      515738 non-null  int64
#  45  reviewer_nationality_4                      515738 non-null  int64
#  46  reviewer_nationality_5                      515738 non-null  int64
#  47  reviewer_nationality_6                      515738 non-null  int64
#  48  reviewer_nationality_7                      515738 non-null  int64
#  49  Negative_Word_Ratio                         515611 non-null  float64
#  50  Positive_Word_Ratio                         515611 non-null  float64
#  51  review_sentiment_ratio                      387848 non-null  float64
#  52  good_present                                515738 non-null  bool
#  53  bad_present                                 515738 non-null  bool
#  54  excellent_present                           515738 non-null  bool
#  55  poor_present                                515738 non-null  bool
#  56  recommend_present                           515738 non-null  bool
# dtypes: bool(5), float64(7), int32(1), int64(34), object(10)
# memory usage: 205.1+ MB

# %% [markdown]
# ### Средняя длина слова в отзыве

# %%
def avg_word_length(text):
    words = text.split()
    if len(words) > 0:
        return sum(len(word) for word in words) / len(words)
    else:
        return 0  # Возвращаем 0, если список пуст

# Создаем новый столбец "avg_word_length" для отрицательных и положительных отзывов
hotels['avg_word_length_negative'] = hotels.loc[hotels['negative_review'].notnull(), 'negative_review'].apply(avg_word_length)
hotels['avg_word_length_positive'] = hotels.loc[hotels['positive_review'].notnull(), 'positive_review'].apply(avg_word_length)

# Выводим средние значения для отрицательных и положительных отзывов
print("Средняя длина слова в отрицательных отзывах:", hotels['avg_word_length_negative'].mean())
print("Средняя длина слова в положительных отзывах:", hotels['avg_word_length_positive'].mean())
# Out:
# Средняя длина слова в отрицательных отзывах: 4.667638229627141
# Средняя длина слова в положительных отзывах: 5.1873011212212194

# %% [markdown]
# ### Работа с датами

# %%
# работа с датами

hotels['review_date'] = pd.to_datetime(hotels['review_date'])
print(f"Data_max: {hotels['review_date'].max()}")
print(f"Data_min: {hotels['review_date'].min()}")
# Out:
# Data_max: 2017-08-03 00:00:00
# Data_min: 2015-08-04 00:00:00

# %%
hotels['review_date'] = pd.to_datetime(hotels['review_date'])  # Преобразуем признак в формат даты.
hotels['review_date_month'] = pd.DatetimeIndex(hotels['review_date']).month # Оставим только месяц.
hotels['days_since_review'] = hotels['days_since_review'].str.replace('days', '').str.replace('day', '').astype('int32')
#hotels = hotels.drop('review_date', axis=1) # Удалим исходный столбец.
hotels.shape
# Out:
# (515738, 60)

# %%
# создаём новые признаки в бинарном формате

encoder = ce.BinaryEncoder(cols=['review_date_month']) # указываем столбец для кодирования.
type_bin = encoder.fit_transform(hotels['review_date_month'])
hotels = pd.concat([hotels, type_bin], axis=1).reset_index()
hotels = hotels.drop('review_date_month', axis=1)
hotels.shape
# Out:
# (515738, 64)

# %%
# работа с тэгами

def collect_tags(df):
    # Эта функция собирает информацию о тегах по типу и количеству
    # Args:
    #    df: input data
    # Returns:
    #    tags_list (список состоящий из списков)
    #    tags_dict (словарь): словарь тегов и их количество
        
    # Создание пустого списка и словаря тегов
    tags_dict = dict()
    tags_list = list()
    
    for item, i in df['tags'].items():
        # Получаем теги из строк, заменяем всё ненужное
        tags = list(i.replace("[' ", '').replace(" ']", '').split(" ', ' "))
        # Заполняем тег лист
        tags_list.append(tags)
        for tag in tags:
            if tag not in tags_dict.keys():
                tags_dict.update({tag: 1})
            else:
                tags_dict[tag] += 1
                
    return tags_list, tags_dict

# Получаем список тегов и словарь тегов и их количество
tags_list, tags_dict = collect_tags(hotels)

# Подсчитываем количество уникальных тегов
unique_tags_count = len(tags_dict)
print("Количество уникальных тегов:", unique_tags_count)

# Создаем новый признак "количество уникальных тегов" в датафрейме hotels
hotels['unique_tags_count'] = unique_tags_count
# Out:
# Количество уникальных тегов: 2428

# %%
from collections import Counter
tags = []
for tag_list in hotels['tags'].values:
    
    tag_list = tag_list.replace("[' ", "")
    tag_list = tag_list.replace(" ']", "")
    tag_list = tag_list.split(" ', ' ")
    tags.extend(tag_list)

# подсчитываем количество тэгов с помощью класса Counter
tag_counter = Counter(tags)
sorted_tags = list(tag_counter.most_common())
sorted_tags[:10]
# Out:
# [('Leisure trip', 417778),
#  ('Submitted from a mobile device', 307640),
#  ('Couple', 252294),
#  ('Stayed 1 night', 193645),
#  ('Stayed 2 nights', 133937),
#  ('Solo traveler', 108545),
#  ('Stayed 3 nights', 95821),
#  ('Business trip', 82939),
#  ('Group', 65392),
#  ('Family with young children', 61015)]

# %%
# извлекаем количество ночей
def get_stayed_nights(tags):
    tags_list = tags.split(' ')
    if 'Stayed' in tags_list:
        night_index = tags_list.index('Stayed') + 1
        return int(tags_list[night_index])
    else:
        return np.NaN

hotels['stayed_nights'] = hotels['tags'].apply(get_stayed_nights)


# дополним датасет ещё 15 колонками-индикаторами самых популярных тэгов
new_columns = []

for tag, count in sorted_tags:
    if 'Stayed' not in tag:
        new_columns.append(tag)    
        
for column in new_columns[:15]:
    hotels[column] = hotels['tags'].apply(lambda x: 1 if column in x else 0)

# %% [markdown]
# ### Работа с негативными и позитивными отзывами

# %%
hotels['negative_review'].head(10)
# Out:
# 0     Would have appreciated a shop in the hotel th...
# 1          No tissue paper box was present at the room
# 2                                             Pillows
# 3                                          No Negative
# 4                                          No Negative
# 5                            They don t have free wifi
# 6     Room generally a bit shabby with some lack of...
# 7     Executive rooms 9th Floor don t have a bath T...
# 8                      Pity about the two days of rain
# 9     Didn t like it at all construction was in pro...
# Name: negative_review, dtype: object

# %%
# создаем признак отсутствия негативных замечаний
hotels['no_negative'] = hotels['negative_review'].apply(lambda i: 1 if i == 'No Negative' else 0)

# %%
hotels['positive_review'].head(10)
# Out:
# 0     Hotel was great clean friendly staff free bre...
# 1                                          No Positive
# 2                           Nice welcoming and service
# 3     Everything including the nice upgrade The Hot...
# 4                      Lovely hotel v welcoming staff
# 5     The location is perfect if you don t have a l...
# 6     Location price It did not cost much more to h...
# 7     Comphy bed upgraded to executive room with ne...
# 8          Its centrality proximity to our destination
# 9     Didn t like anything about the stay if i had ...
# Name: positive_review, dtype: object

# %%
# аналогичный признак отсутствия позитива в отзыве
hotels['no_positive'] = hotels['positive_review'].apply(lambda i: 1 if i == 'No Positive' else 0)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
# из отзывов выделим эмоциональную окраску текста в отзывах
nltk.downloader.download('vader_lexicon')
sent_analyzer = SentimentIntensityAnalyzer()


# в результате обработки выдается словарь с четырьмя парами ключ:значение
# по негативным отзывам
hotels['negative_review'] = hotels['negative_review'].apply(sent_analyzer.polarity_scores)
# по позитивным отзывам
hotels['positive_review'] = hotels['positive_review'].apply(sent_analyzer.polarity_scores)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# создадим новые признаки из негативнного отзыва
hotels['negative_neg'] = hotels['negative_review'].apply(lambda x: x['neg'])
hotels['negative_neu'] = hotels['negative_review'].apply(lambda x: x['neu'])
hotels['negative_pos'] = hotels['negative_review'].apply(lambda x: x['pos'])
hotels['negative_compound'] = hotels['negative_review'].apply(lambda x: x['compound'])

# создадим новые признаки из позитивного отзыва
hotels['positive_neg'] = hotels['positive_review'].apply(lambda x: x['neg'])
hotels['positive_neu'] = hotels['positive_review'].apply(lambda x: x['neu'])
hotels['positive_pos'] = hotels['positive_review'].apply(lambda x: x['pos'])
hotels['positive_compound'] = hotels['positive_review'].apply(lambda x: x['compound'])

# %%
# удалим ненужные теперь признаки отзывов
hotels.drop(['negative_review', 'positive_review'], axis=1, inplace=True)

# %% [markdown]
# ### Обработка пропущенных значений

# %%
from sklearn.impute import SimpleImputer

# Создание экземпляра SimpleImputer с выбранным методом заполнения (mean или median)
imputer = SimpleImputer(strategy='mean')  # Или strategy='median'

# Заполнение пропущенных значений в признаке 'Negative_Word_Ratio' средним значением
hotels['Negative_Word_Ratio'] = imputer.fit_transform(hotels[['Negative_Word_Ratio']])

# Заполнение пропущенных значений в признаке 'Positive_Word_Ratio' средним значением
hotels['Positive_Word_Ratio'] = imputer.fit_transform(hotels[['Positive_Word_Ratio']])

# Заполнение пропущенных значений в признаке 'review_sentiment_ratio' средним значением
hotels['review_sentiment_ratio'] = imputer.fit_transform(hotels[['review_sentiment_ratio']])

# %% [markdown]
# ### Рассчитываем среднее количество отзывов на одного рецензента

# %%
# Группировка данных по рецензенту и вычисление среднего количества отзывов
reviewer_avg_reviews = hotels.groupby('reviewer_nationality')['total_number_of_reviews_reviewer_has_given'].mean()

# Создание нового столбца 'avg_reviews_per_reviewer' и заполнение средними значениями
hotels['avg_reviews_per_reviewer'] = hotels['reviewer_nationality'].map(reviewer_avg_reviews)

# Вывод среднего значения для всего датасета
print("Среднее количество отзывов на одного рецензента:", hotels['avg_reviews_per_reviewer'].mean())
# Out:
# Среднее количество отзывов на одного рецензента: 7.1660009539727545

# %%
hotels['avg_reviews_per_reviewer']
# Out:
# 0          5.173299
# 1         12.236777
# 2          9.375891
# 3          5.212546
# 4          5.173299
#             ...
# 515733    10.756853
# 515734    10.472814
# 515735    11.931145
# 515736     8.539521
# 515737     8.467398
# Name: avg_reviews_per_reviewer, Length: 515738, dtype: float64

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 90 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   index                                       515738 non-null  int64
#  1   hotel_address                               515738 non-null  object
#  2   additional_number_of_scoring                515738 non-null  int64
#  3   review_date                                 515738 non-null  datetime64[ns]
#  4   average_score                               515738 non-null  float64
#  5   hotel_name                                  515738 non-null  object
#  6   reviewer_nationality                        515738 non-null  object
#  7   review_total_negative_word_counts           515738 non-null  int64
#  8   total_number_of_reviews                     515738 non-null  int64
#  9   review_total_positive_word_counts           515738 non-null  int64
#  10  total_number_of_reviews_reviewer_has_given  515738 non-null  int64
#  11  tags                                        515738 non-null  object
#  12  days_since_review                           515738 non-null  int32
#  13  sample                                      515738 non-null  int64
#  14  reviewer_score                              515738 non-null  float64
#  15  unique_names                                515738 non-null  int64
#  16  country                                     515738 non-null  object
#  17  city                                        515738 non-null  object
#  18  city_population                             515738 non-null  float64
#  19  London                                      515738 non-null  int64
#  20  Paris                                       515738 non-null  int64
#  21  Amsterdam                                   515738 non-null  int64
#  22  Milan                                       515738 non-null  int64
#  23  Vienna                                      515738 non-null  int64
#  24  Barcelona                                   515738 non-null  int64
#  25  center_distance                             515738 non-null  float64
#  26  hotel_name_0                                515738 non-null  int64
#  27  hotel_name_1                                515738 non-null  int64
#  28  hotel_name_2                                515738 non-null  int64
#  29  hotel_name_3                                515738 non-null  int64
#  30  hotel_name_4                                515738 non-null  int64
#  31  hotel_name_5                                515738 non-null  int64
#  32  hotel_name_6                                515738 non-null  int64
#  33  hotel_name_7                                515738 non-null  int64
#  34  hotel_name_8                                515738 non-null  int64
#  35  hotel_name_9                                515738 non-null  int64
#  36  hotel_name_10                               515738 non-null  int64
#  37  country_encoded                             515738 non-null  int32
#  38  hotel_category                              515738 non-null  int64
#  39  local_reviewer                              515738 non-null  int64
#  40  reviewer_nationality_0                      515738 non-null  int64
#  41  reviewer_nationality_1                      515738 non-null  int64
#  42  reviewer_nationality_2                      515738 non-null  int64
#  43  reviewer_nationality_3                      515738 non-null  int64
#  44  reviewer_nationality_4                      515738 non-null  int64
#  45  reviewer_nationality_5                      515738 non-null  int64
#  46  reviewer_nationality_6                      515738 non-null  int64
#  47  reviewer_nationality_7                      515738 non-null  int64
#  48  Negative_Word_Ratio                         515738 non-null  float64
#  49  Positive_Word_Ratio                         515738 non-null  float64
#  50  review_sentiment_ratio                      515738 non-null  float64
#  51  good_present                                515738 non-null  bool
#  52  bad_present                                 515738 non-null  bool
#  53  excellent_present                           515738 non-null  bool
#  54  poor_present                                515738 non-null  bool
#  55  recommend_present                           515738 non-null  bool
#  56  avg_word_length_negative                    515738 non-null  float64
#  57  avg_word_length_positive                    515738 non-null  float64
#  58  review_date_month_0                         515738 non-null  int64
#  59  review_date_month_1                         515738 non-null  int64
#  60  review_date_month_2                         515738 non-null  int64
#  61  review_date_month_3                         515738 non-null  int64
#  62  unique_tags_count                           515738 non-null  int64
#  63  stayed_nights                               515546 non-null  float64
#  64  Leisure trip                                515738 non-null  int64
#  65  Submitted from a mobile device              515738 non-null  int64
#  66  Couple                                      515738 non-null  int64
#  67  Solo traveler                               515738 non-null  int64
#  68  Business trip                               515738 non-null  int64
#  69  Group                                       515738 non-null  int64
#  70  Family with young children                  515738 non-null  int64
#  71  Double Room                                 515738 non-null  int64
#  72  Standard Double Room                        515738 non-null  int64
#  73  Superior Double Room                        515738 non-null  int64
#  74  Family with older children                  515738 non-null  int64
#  75  Deluxe Double Room                          515738 non-null  int64
#  76  Double or Twin Room                         515738 non-null  int64
#  77  Standard Double or Twin Room                515738 non-null  int64
#  78  Classic Double Room                         515738 non-null  int64
#  79  no_negative                                 515738 non-null  int64
#  80  no_positive                                 515738 non-null  int64
#  81  negative_neg                                515738 non-null  float64
#  82  negative_neu                                515738 non-null  float64
#  83  negative_pos                                515738 non-null  float64
#  84  negative_compound                           515738 non-null  float64
#  85  positive_neg                                515738 non-null  float64
#  86  positive_neu                                515738 non-null  float64
#  87  positive_pos                                515738 non-null  float64
#  88  positive_compound                           515738 non-null  float64
#  89  avg_reviews_per_reviewer                    515738 non-null  float64
# dtypes: bool(5), datetime64[ns](1), float64(19), int32(2), int64(57), object(6)
# memory usage: 333.0+ MB

# %% [markdown]
# ### Масштабирование признаков

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import  MinMaxScaler
# Признаки, которые необходимо масштабировать
features_to_scale = ['additional_number_of_scoring', 'average_score', 'review_total_negative_word_counts', 'total_number_of_reviews']

# Применяем стандартизацию
scaler = StandardScaler()
hotels_scaled_standard = hotels.copy()
hotels_scaled_standard[features_to_scale] = scaler.fit_transform(hotels[features_to_scale])

# Применяем нормализацию
scaler = MinMaxScaler()
hotels_scaled_minmax = hotels.copy()
hotels_scaled_minmax[features_to_scale] = scaler.fit_transform(hotels[features_to_scale])
hotels_scaled_minmax[features_to_scale]
# Out:
#         additional_number_of_scoring  average_score  \
# 0                           0.336815       0.630435
# 1                           0.227900       0.739130
# 2                           0.016785       0.673913
# 3                           0.089519       0.847826
# 4                           0.310705       0.847826
# ...                              ...            ...
# 515733                      0.039537       0.826087
# 515734                      0.101082       0.695652
# 515735                      0.170086       0.347826
# 515736                      0.135770       0.630435
# 515737                      0.082432       0.826087
#
#         review_total_negative_word_counts  total_number_of_reviews
# 0                                0.127451                 1.000000
# 1                                0.024510                 0.299212
# 2                                0.007353                 0.018524
# 3                                0.000000                 0.090215
# 4                                0.000000                 0.279305
# ...                                   ...                      ...
# 515733                           0.000000                 0.034522
# 515734                           0.000000                 0.191315
# 515735                           0.029412                 0.162868
# 515736                           0.000000                 0.091658
# 515737                           0.049020                 0.070127
#
# [515738 rows x 4 columns]

# %% [markdown]
# # Оценка мультиколлинеарности признаков

# %%
import seaborn as sns 
d_hotels= hotels.drop(['hotel_address', 'hotel_name', 'reviewer_nationality', 
                       'country', 'city', 'tags'], axis=1)
df_corr = d_hotels.corr()
result_columns = []
for column in df_corr:
    col_data = df_corr[column]
    if col_data.min() < -0.8 or col_data.sort_values(ascending=False)[1] > 0.8:
        result_columns.append(column)
result_columns.append('reviewer_score')
        
plt.rcParams['figure.figsize'] = (15,10)
sns.heatmap(hotels[result_columns].corr(), annot=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1424\2423163058.py:8: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# <Axes: >

# %%
# рассмотрим признаки, между которыми наблюдается сильная связь
for row in df_corr.index:
    for col in df_corr.columns:
        if df_corr.loc[row, col] != 1 and abs(df_corr.loc[row, col]) >= 0.7:
            print(row, col, '-', round(abs(df_corr.loc[row, col]), 3))
# Out:
# index sample - 0.75
# additional_number_of_scoring total_number_of_reviews - 0.825
# review_date days_since_review - 1.0
# total_number_of_reviews additional_number_of_scoring - 0.825
# days_since_review review_date - 1.0
# sample index - 0.75
# sample reviewer_score - 0.932
# reviewer_score sample - 0.932
# city_population Milan - 0.996
# city_population country_encoded - 0.787
# Milan city_population - 0.996
# Milan country_encoded - 0.82
# country_encoded city_population - 0.787
# country_encoded Milan - 0.82
# hotel_category Business trip - 0.91
# Negative_Word_Ratio Positive_Word_Ratio - 1.0
# Negative_Word_Ratio no_negative - 0.74
# Positive_Word_Ratio Negative_Word_Ratio - 1.0
# Positive_Word_Ratio no_negative - 0.74
# Leisure trip Business trip - 0.904
# Business trip hotel_category - 0.91
# Business trip Leisure trip - 0.904
# no_negative Negative_Word_Ratio - 0.74
# no_negative Positive_Word_Ratio - 0.74
# no_negative negative_neg - 0.948
# no_negative negative_neu - 0.905
# no_positive positive_neg - 0.911
# negative_neg no_negative - 0.948
# negative_neg negative_neu - 0.945
# negative_neg negative_compound - 0.738
# negative_neu no_negative - 0.905
# negative_neu negative_neg - 0.945
# negative_compound negative_neg - 0.738
# positive_neg no_positive - 0.911
# positive_neu positive_pos - 0.924
# positive_pos positive_neu - 0.924

# %% [markdown]
# ### Анализ выбросов

# %%
#Объявляем функцию, реализующую фильтрацию выбросов по методу z-отклонений
def outliers_z_score(hotels, feature, log_scale=False):
    if log_scale:
        x = np.log(hotels[feature]+1)
    else:
        x = hotels[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - 3 * sigma
    upper_bound = mu + 3 * sigma
    outliers = hotels[(x < lower_bound) | (x > upper_bound)]
    cleaned = hotels[(x > lower_bound) & (x < upper_bound)]
     # Построение графика выбросов
    plt.figure(figsize=(10, 6))
    plt.scatter(cleaned.index, cleaned[feature], color='blue', label='Inliers')
    plt.scatter(outliers.index, outliers[feature], color='red', label='Outliers')
    plt.xlabel('Index')
    plt.ylabel(feature)
    plt.title('Outliers Detection - Z-Score Method')
    plt.legend()
    plt.show()
    
    return outliers, cleaned

outliers, cleaned = outliers_z_score(hotels, 'average_score')
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Creating legend with loc="best" can be slow with large amounts of data.

# %% [markdown]
# ### Удаление нечисловых признаков

# %%
# убираем признаки которые еще не успели обработать
object_columns = [i for i in hotels.columns if hotels[i].dtypes == 'object']

hotels.drop(object_columns, axis=1, inplace=True)
# заполняем пропуски самым простым способом
hotels = hotels.fillna(0)

# %%
hotels.drop('review_date', axis=1, inplace=True)

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 83 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   index                                       515738 non-null  int64
#  1   additional_number_of_scoring                515738 non-null  int64
#  2   average_score                               515738 non-null  float64
#  3   review_total_negative_word_counts           515738 non-null  int64
#  4   total_number_of_reviews                     515738 non-null  int64
#  5   review_total_positive_word_counts           515738 non-null  int64
#  6   total_number_of_reviews_reviewer_has_given  515738 non-null  int64
#  7   days_since_review                           515738 non-null  int32
#  8   sample                                      515738 non-null  int64
#  9   reviewer_score                              515738 non-null  float64
#  10  unique_names                                515738 non-null  int64
#  11  city_population                             515738 non-null  float64
#  12  London                                      515738 non-null  int64
#  13  Paris                                       515738 non-null  int64
#  14  Amsterdam                                   515738 non-null  int64
#  15  Milan                                       515738 non-null  int64
#  16  Vienna                                      515738 non-null  int64
#  17  Barcelona                                   515738 non-null  int64
#  18  center_distance                             515738 non-null  float64
#  19  hotel_name_0                                515738 non-null  int64
#  20  hotel_name_1                                515738 non-null  int64
#  21  hotel_name_2                                515738 non-null  int64
#  22  hotel_name_3                                515738 non-null  int64
#  23  hotel_name_4                                515738 non-null  int64
#  24  hotel_name_5                                515738 non-null  int64
#  25  hotel_name_6                                515738 non-null  int64
#  26  hotel_name_7                                515738 non-null  int64
#  27  hotel_name_8                                515738 non-null  int64
#  28  hotel_name_9                                515738 non-null  int64
#  29  hotel_name_10                               515738 non-null  int64
#  30  country_encoded                             515738 non-null  int32
#  31  hotel_category                              515738 non-null  int64
#  32  local_reviewer                              515738 non-null  int64
#  33  reviewer_nationality_0                      515738 non-null  int64
#  34  reviewer_nationality_1                      515738 non-null  int64
#  35  reviewer_nationality_2                      515738 non-null  int64
#  36  reviewer_nationality_3                      515738 non-null  int64
#  37  reviewer_nationality_4                      515738 non-null  int64
#  38  reviewer_nationality_5                      515738 non-null  int64
#  39  reviewer_nationality_6                      515738 non-null  int64
#  40  reviewer_nationality_7                      515738 non-null  int64
#  41  Negative_Word_Ratio                         515738 non-null  float64
#  42  Positive_Word_Ratio                         515738 non-null  float64
#  43  review_sentiment_ratio                      515738 non-null  float64
#  44  good_present                                515738 non-null  bool
#  45  bad_present                                 515738 non-null  bool
#  46  excellent_present                           515738 non-null  bool
#  47  poor_present                                515738 non-null  bool
#  48  recommend_present                           515738 non-null  bool
#  49  avg_word_length_negative                    515738 non-null  float64
#  50  avg_word_length_positive                    515738 non-null  float64
#  51  review_date_month_0                         515738 non-null  int64
#  52  review_date_month_1                         515738 non-null  int64
#  53  review_date_month_2                         515738 non-null  int64
#  54  review_date_month_3                         515738 non-null  int64
#  55  unique_tags_count                           515738 non-null  int64
#  56  stayed_nights                               515738 non-null  float64
#  57  Leisure trip                                515738 non-null  int64
#  58  Submitted from a mobile device              515738 non-null  int64
#  59  Couple                                      515738 non-null  int64
#  60  Solo traveler                               515738 non-null  int64
#  61  Business trip                               515738 non-null  int64
#  62  Group                                       515738 non-null  int64
#  63  Family with young children                  515738 non-null  int64
#  64  Double Room                                 515738 non-null  int64
#  65  Standard Double Room                        515738 non-null  int64
#  66  Superior Double Room                        515738 non-null  int64
#  67  Family with older children                  515738 non-null  int64
#  68  Deluxe Double Room                          515738 non-null  int64
#  69  Double or Twin Room                         515738 non-null  int64
#  70  Standard Double or Twin Room                515738 non-null  int64
#  71  Classic Double Room                         515738 non-null  int64
#  72  no_negative                                 515738 non-null  int64
#  73  no_positive                                 515738 non-null  int64
#  74  negative_neg                                515738 non-null  float64
#  75  negative_neu                                515738 non-null  float64
#  76  negative_pos                                515738 non-null  float64
#  77  negative_compound                           515738 non-null  float64
#  78  positive_neg                                515738 non-null  float64
#  79  positive_neu                                515738 non-null  float64
#  80  positive_pos                                515738 non-null  float64
#  81  positive_compound                           515738 non-null  float64
#  82  avg_reviews_per_reviewer                    515738 non-null  float64
# dtypes: bool(5), float64(19), int32(2), int64(57)
# memory usage: 305.4 MB

# %% [markdown]
# ### Создание и обучение модели

# %%
# Разбиваем датафрейм на части, необходимые для обучения и тестирования модели  
# Х - данные с информацией об отелях, у - целевая переменная (рейтинги отелей)  
train_data = hotels.query('sample == 1').drop(['sample'], axis=1) 
test_data = hotels.query('sample == 0').drop(['sample'], axis=1)

y = train_data.reviewer_score.values # наша цель
X = train_data.drop(['reviewer_score'], axis=1)

# %%
# Загружаем специальный инструмент для разбивки:  
from sklearn.model_selection import train_test_split

# %%
# Наборы данных с меткой "train" будут использоваться для обучения модели, "test" - для тестирования.  
# Для тестирования мы будем использовать 25% от исходного датасета.  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# проверка
test_data.shape, train_data.shape, X.shape, X_train.shape, X_test.shape
# Out:
# ((128935, 82), (386803, 82), (386803, 81), (290102, 81), (96701, 81))

# %%
# Импортируем необходимые библиотеки:  
from sklearn.ensemble import RandomForestRegressor # инструмент для создания и обучения модели  
from sklearn import metrics # инструменты для оценки точности модели  
  
# Создаём модель  
model = RandomForestRegressor(n_estimators=100, verbose=1, n_jobs=-1, random_state=42)

# %%
# Обучаем модель на тестовом наборе данных  
model.fit(X_train, y_train)  
      
# Используем обученную модель для предсказания рейтинга отелей в тестовой выборке.  
# Предсказанные значения записываем в переменную y_pred  
y_pred = model.predict(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 10.4min finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    3.5s finished

# %%
# Функция для рассчёта MAPE:
def mape(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
   
# Сравниваем предсказанные значения (y_pred) с реальными (y_test), и смотрим насколько они в среднем отличаются
# Метрика называется Mean Absolute Error (MAE) и показывает среднее отклонение предсказанных значений от фактических.
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 0.8572035759712926

# %%
# Метрика называется Mean Absolute Percentage Error (MAPE) и показывает среднюю абсолютную процентную ошибку предсказанных значений от фактических.  
print('MAPE:', mape(y_test, y_pred))
# Out:
# MAPE: 12.229369762496113

# %% [markdown]
# ### Предсказание по тестовым данным

# %%
plt.rcParams['figure.figsize'] = (10,10)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(40).plot(kind='barh')
# Out:
# <Axes: >

# %%
feat_importances.nlargest(15).index
# Out:
# Index(['Positive_Word_Ratio', 'review_sentiment_ratio', 'average_score',
#        'positive_compound', 'negative_compound', 'avg_word_length_negative',
#        'avg_word_length_positive', 'index', 'days_since_review',
#        'Negative_Word_Ratio', 'center_distance',
#        'review_total_negative_word_counts', 'total_number_of_reviews',
#        'additional_number_of_scoring', 'avg_reviews_per_reviewer'],
#       dtype='object')

# %%
sample_submission
# Out:
#         reviewer_score      id
# 0                    1  488440
# 1                   10  274649
# 2                    3  374688
# 3                   10  404352
# 4                    9  451596
# ...                ...     ...
# 128930               7  495812
# 128931               1  315577
# 128932               3  511968
# 128933               6  303386
# 128934               5  103157
#
# [128935 rows x 2 columns]

# %%
test_data = test_data.drop(['reviewer_score'], axis=1)

# %%
predict_submission = model.predict(test_data)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    4.0s finished

# %%
predict_submission
# Out:
# array([8.442, 7.654, 8.147, ..., 7.938, 9.353, 6.522])

# %%
list(sample_submission)
# Out:
# ['reviewer_score', 'id']

# %% [markdown]
# ### Подготовка сабмишена

# %%
sample_submission['reviewer_score'] = predict_submission
sample_submission.to_csv('submission.csv', index=False)
sample_submission.head(10)
# Out:
#    reviewer_score      id
# 0           8.442  488440
# 1           7.654  274649
# 2           8.147  374688
# 3           9.580  404352
# 4           9.406  451596
# 5           8.503  302161
# 6           7.589  317079
# 7           7.562   13963
# 8           8.784  159785
# 9           7.388  195089
